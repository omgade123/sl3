# %%
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt

# %%
titanic = sn.load_dataset('titanic')
sn.load_dataset('titanic')
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
dummy_column=pd.get_dummies(titanic.deck)  #This function is used for creating dummy variables from categorical variables. in pandas
#in this case its deck A, B,C ...where each deck(qalatative data)becomes new column and has values true and fale
#Ex for A clounm if row has A then True otherwise fale

# %%
new_df=titanic.join(dummy_column).drop(['deck'],axis=1)

# %%
new_df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
titanic['age'].dropna()
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 885    39.0
# 886    27.0
# 887    19.0
# 889    26.0
# 890    32.0
# Name: age, Length: 714, dtype: float64

# %%
titanic['embarked'].dropna()
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: embarked, Length: 889, dtype: object

# %%
titanic['embark_town'].dropna()
# Out:
# 0      Southampton
# 1        Cherbourg
# 2      Southampton
# 3      Southampton
# 4      Southampton
#           ...
# 886    Southampton
# 887    Southampton
# 888    Southampton
# 889      Cherbourg
# 890     Queenstown
# Name: embark_town, Length: 889, dtype: object

# %%
sn.distplot(x = titanic['age'], bins = 10) #specify the number of intervals into which the data range is divided.
# Out:
# C:\Users\Om\AppData\Local\Temp\ipykernel_9328\379149057.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(x = titanic['age'], bins = 10) #specify the number of intervals into which the data range is divided.
# C:\Users\Om\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: ylabel='Density'>

# %%
sn.jointplot(x = titanic['age'], y = titanic['fare'], kind = 'scatter')
# Out:
# C:\Users\Om\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Om\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sn.jointplot(x = titanic['age'], y = titanic['fare'], kind = 'hex')
# Out:
# C:\Users\Om\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Om\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sn.rugplot(titanic['fare'])
# Out:
# C:\Users\Om\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='fare'>

# %%
sn.boxplot(x='sex', y='age', data=titanic)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sn.boxplot(x='sex', y='age', data=titanic, hue='survived')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sn.barplot(x="sex", y="age", data=titanic)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sn.barplot(x='sex', y='age', data=titanic, estimator=np.std) #estimator=np.std means that sd(np.std) of data within each category will be calculated and used to determine the height of the bars in the bar plot.
# Out:
# C:\Users\Om\anaconda3\Lib\site-packages\numpy\lib\nanfunctions.py:1384: RuntimeWarning: All-NaN slice encountered
#   return _nanquantile_unchecked(
# <Axes: xlabel='sex', ylabel='age'>

# %%
sn.countplot(x='sex', data=titanic)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sn.violinplot(x='sex', y='age', data=titanic, hue='survived')
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sn.stripplot(x='sex', y='age', data=titanic, jitter=True, hue='survived')
# Out:
# C:\Users\Om\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Om\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='sex', ylabel='age'>

# %%
 sn.swarmplot(x='sex', y='age', data=titanic, hue='survived')
# Out:
# C:\Users\Om\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Om\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='sex', ylabel='age'>

# %%
male_passengers = titanic[titanic['sex'] == 'male']
female_passengers = titanic[titanic['sex'] == 'female']

# Select numerical columns for analysis
numerical_columns = ['age', 'fare', 'pclass']

# Calculate correlation matrices for male and female passengers  
#A correlation matrix is a table that displays the correlation coefficients between multiple variables. 
corr_male = male_passengers[numerical_columns].corr()
corr_female = female_passengers[numerical_columns].corr()

# Plot heatmaps
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sn.heatmap(corr_male, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap - Male Passengers')

plt.subplot(1, 2, 2)
sn.heatmap(corr_female, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap - Female Passengers')

plt.tight_layout()
plt.show()
